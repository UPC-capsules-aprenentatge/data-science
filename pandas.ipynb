# %% [markdown]
# **Series de Pandas**

# %%
import pandas as pd

precipitation = [1, 7, 2]

myvar = pd.Series()

print(myvar)
print("==========")
print(myvar[0])
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64
# ==========
# 1

# %% [markdown]
# *Labels*

# %%
import pandas as pd

precipitation = [15.4, 70, 2, 24]


myvar = pd.Series(precipitation, index = ["avgAirTemperature", "precipitation", "minAirTemperature","maxAirTemperature"])

print(myvar)
print("==========")
print(myvar["avgAirTemperature"])
print(myvar["precipitation"])
print(myvar["minAirTemperature"])
print(myvar["maxAirTemperature"])
# Out:
# avgAirTemperature    15.4
# precipitation        70.0
# minAirTemperature     2.0
# maxAirTemperature    24.0
# dtype: float64
# ==========
# 15.4
# 70.0
# 2.0
# 24.0

# %% [markdown]
# *Key/Value Objects*

# %%
import pandas as pd

precipitation = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(precipitation)

print(myvar)

print("==========")

myvar2 = pd.Series(precipitation, index = ["day1", "day2"])

print(myvar2)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64
# ==========
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# **DATA FRAMES**

# %%
import pandas as pd

mydataset = {
  'day': ["1", "2", "3"],
  'precipitation': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#   day  precipitation
# 0   1              3
# 1   2              7
# 2   3              2

# %%
import pandas as pd

data = {
  "precipitation": [420, 380, 390],
  "avgAirTemperature": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)

print("==========")

print(myvar.loc[0])
print("-----------")
print(myvar.loc[1])
print("-----------")
print(myvar.loc[2])
print("-----------")
print(myvar.loc[[0, 2]])
# Out:
#    precipitation  avgAirTemperature
# 0            420                 50
# 1            380                 40
# 2            390                 45
# ==========
# precipitation        420
# avgAirTemperature     50
# Name: 0, dtype: int64
# -----------
# precipitation        380
# avgAirTemperature     40
# Name: 1, dtype: int64
# -----------
# precipitation        390
# avgAirTemperature     45
# Name: 2, dtype: int64
# -----------
#    precipitation  avgAirTemperature
# 0            420                 50
# 2            390                 45

# %% [markdown]
# *Named Indexes*

# %%
import pandas as pd

data = {
  "precipitation": [420, 380, 390],
  "avgAirTemperature": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
print(df.loc["day1"])
print("-----------")
print(df.loc["day2"])
print("-----------")
print(df.loc["day3"])
print("-----------")
print(df.loc[["day1", "day3"]])
# Out:
#       precipitation  avgAirTemperature
# day1            420                 50
# day2            380                 40
# day3            390                 45
# precipitation        420
# avgAirTemperature     50
# Name: day1, dtype: int64
# -----------
# precipitation        380
# avgAirTemperature     40
# Name: day2, dtype: int64
# -----------
# precipitation        390
# avgAirTemperature     45
# Name: day3, dtype: int64
# -----------
#       precipitation  avgAirTemperature
# day1            420                 50
# day3            390                 45

# %% [markdown]
# *Analyzing DataFrames*

# %%
import pandas as pd

#pd.options.display.max_rows = 9999
df = pd.read_csv('weatherData.csv')

#print(df)
print("-------------------------------")
print(df.info())
print("-------------------------------")
print(df.head(10))
print("-----------")
# last 5 rows
print(df.tail())
# Out:
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   lastUpdated                            3487 non-null   object
#  1   weatherStation.name                    3487 non-null   object
#  2   weatherStation.province                3487 non-null   object
#  3   weatherStation.location.coordinates.0  3487 non-null   float64
#  4   weatherStation.location.coordinates.1  3487 non-null   float64
#  5   avgAirTemperature                      3458 non-null   float64
#  6   precipitation                          3480 non-null   float64
#  7   minAirTemperature                      3468 non-null   float64
#  8   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 245.3+ KB
# None
# -------------------------------
#                 lastUpdated weatherStation.name weatherStation.province  \
# 0  2023-11-16T20:38:37.792Z             MANRESA               BARCELONA
# 1  2023-11-16T20:38:37.820Z             MANRESA               BARCELONA
# 2  2023-11-16T20:38:37.823Z             MANRESA               BARCELONA
# 3  2023-11-16T20:38:37.825Z             MANRESA               BARCELONA
# 4  2023-11-16T20:38:37.827Z             MANRESA               BARCELONA
# 5  2023-11-16T20:38:37.830Z             MANRESA               BARCELONA
# 6  2023-11-16T20:38:37.833Z             MANRESA               BARCELONA
# 7  2023-11-16T20:38:37.836Z             MANRESA               BARCELONA
# 8  2023-11-16T20:38:37.838Z             MANRESA               BARCELONA
# 9  2023-11-16T20:38:37.840Z             MANRESA               BARCELONA
#
#    weatherStation.location.coordinates.0  \
# 0                                  41.72
# 1                                  41.72
# 2                                  41.72
# 3                                  41.72
# 4                                  41.72
# 5                                  41.72
# 6                                  41.72
# 7                                  41.72
# 8                                  41.72
# 9                                  41.72
#
#    weatherStation.location.coordinates.1  avgAirTemperature  precipitation  \
# 0                               1.840278               18.4            0.0
# 1                               1.840278               17.0            0.0
# 2                               1.840278               14.9            0.2
# 3                               1.840278               14.0            0.0
# 4                               1.840278               11.8            0.0
# 5                               1.840278               12.2            0.0
# 6                               1.840278               12.5            0.0
# 7                               1.840278               13.6            0.0
# 8                               1.840278               14.4            0.0
# 9                               1.840278               15.6            0.0
#
#    minAirTemperature  maxAirTemperature
# 0               11.2               25.5
# 1               11.1               22.9
# 2               11.0               18.8
# 3                8.7               19.2
# 4                4.6               18.9
# 5                2.0               22.4
# 6                3.2               21.8
# 7                5.1               22.1
# 8                8.2               20.7
# 9                9.6               21.6
# -----------
#                    lastUpdated   weatherStation.name weatherStation.province  \
# 3482  2024-03-15T04:00:00.919Z      BARCELONA, FABRA               BARCELONA
# 3483  2024-03-15T04:00:01.588Z  BARCELONA AEROPUERTO               BARCELONA
# 3484  2024-03-15T04:00:04.879Z             BARCELONA               BARCELONA
# 3485  2024-03-15T04:05:01.893Z            Muntanyola               Barcelona
# 3486  2024-03-15T04:05:01.910Z                 Òdena               Barcelona
#
#       weatherStation.location.coordinates.0  \
# 3482                              41.418333
# 3483                              41.292778
# 3484                              41.390556
# 3485                              41.878130
# 3486                              41.586420
#
#       weatherStation.location.coordinates.1  avgAirTemperature  precipitation  \
# 3482                               2.124167          11.000000            0.0
# 3483                               2.070000          13.000000            0.0
# 3484                               2.200000          14.000000            0.0
# 3485                               2.178730          10.842857            0.0
# 3486                               1.653060          10.271429            0.0
#
#       minAirTemperature  maxAirTemperature
# 3482                6.0               17.0
# 3483                8.0               19.0
# 3484                9.0               18.0
# 3485                9.8               12.3
# 3486                9.6               10.6

# %% [markdown]
# Data cleaning

# %%
import pandas as pd
#pd.options.display.max_rows = 9999
df = pd.read_csv('weatherData.csv')

print("-------------------------------")
print(df.info())
print("-------------------------------")

df.insert(0, 'ID', range(1, 1 + len(df)))

print("-------------------------------")
print(df.info())
print("-------------------------------")

print(df.loc[236])
print(df.loc[251])
print(df.loc[682])
print(df.loc[1220])
print(df.loc[1221])
print(df.loc[1322])


df["avgAirTemperature"].fillna(999, inplace=True)
df["precipitation"].fillna(999, inplace=True)
df["minAirTemperature"].fillna(999, inplace=True)
df["maxAirTemperature"].fillna(999, inplace=True)
print("-------------------------------")
print(df.loc[236])
print(df.loc[251])
print(df.loc[682])
print(df.loc[1220])
print(df.loc[1221])
print(df.loc[1322])
# Out:
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   lastUpdated                            3487 non-null   object
#  1   weatherStation.name                    3487 non-null   object
#  2   weatherStation.province                3487 non-null   object
#  3   weatherStation.location.coordinates.0  3487 non-null   float64
#  4   weatherStation.location.coordinates.1  3487 non-null   float64
#  5   avgAirTemperature                      3458 non-null   float64
#  6   precipitation                          3480 non-null   float64
#  7   minAirTemperature                      3468 non-null   float64
#  8   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 245.3+ KB
# None
# -------------------------------
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ID                                     3487 non-null   int64
#  1   lastUpdated                            3487 non-null   object
#  2   weatherStation.name                    3487 non-null   object
#  3   weatherStation.province                3487 non-null   object
#  4   weatherStation.location.coordinates.0  3487 non-null   float64
#  5   weatherStation.location.coordinates.1  3487 non-null   float64
#  6   avgAirTemperature                      3458 non-null   float64
#  7   precipitation                          3480 non-null   float64
#  8   minAirTemperature                      3468 non-null   float64
#  9   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 272.5+ KB
# None
# -------------------------------
# ID                                                            237
# lastUpdated                              2023-11-16T20:38:38.276Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 NaN
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 236, dtype: object
# ID                                                            252
# lastUpdated                              2023-11-16T20:38:38.302Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 251, dtype: object
# ID                                                            683
# lastUpdated                              2023-11-16T20:49:47.780Z
# weatherStation.name                                     PORQUERES
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   42.104444
# weatherStation.location.coordinates.1                    2.763611
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 682, dtype: object
# ID                                                           1221
# lastUpdated                              2023-11-20T10:42:29.123Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1220, dtype: object
# ID                                                           1222
# lastUpdated                              2023-11-20T10:42:29.124Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1221, dtype: object
# ID                                                           1323
# lastUpdated                              2023-11-20T10:42:29.226Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1322, dtype: object
# -------------------------------
# ID                                                            237
# lastUpdated                              2023-11-16T20:38:38.276Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                           999.0
# precipitation                                               999.0
# minAirTemperature                                           999.0
# maxAirTemperature                                           999.0
# Name: 236, dtype: object
# ID                                                            252
# lastUpdated                              2023-11-16T20:38:38.302Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                           999.0
# precipitation                                                 0.0
# minAirTemperature                                           999.0
# maxAirTemperature                                           999.0
# Name: 251, dtype: object
# ID                                                            683
# lastUpdated                              2023-11-16T20:49:47.780Z
# weatherStation.name                                     PORQUERES
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   42.104444
# weatherStation.location.coordinates.1                    2.763611
# avgAirTemperature                                           999.0
# precipitation                                                 0.0
# minAirTemperature                                           999.0
# maxAirTemperature                                           999.0
# Name: 682, dtype: object
# ID                                                           1221
# lastUpdated                              2023-11-20T10:42:29.123Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                           999.0
# precipitation                                                 0.0
# minAirTemperature                                           999.0
# maxAirTemperature                                           999.0
# Name: 1220, dtype: object
# ID                                                           1222
# lastUpdated                              2023-11-20T10:42:29.124Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                           999.0
# precipitation                                                 0.0
# minAirTemperature                                           999.0
# maxAirTemperature                                           999.0
# Name: 1221, dtype: object
# ID                                                           1323
# lastUpdated                              2023-11-20T10:42:29.226Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                           999.0
# precipitation                                                 0.0
# minAirTemperature                                           999.0
# maxAirTemperature                                           999.0
# Name: 1322, dtype: object

# %%
import pandas as pd

#pd.options.display.max_rows = 9999
df = pd.read_csv('weatherData.csv')

#print(df)
print("-------------------------------")
print(df.info())
print("-------------------------------")

df.insert(0, 'ID', range(1, 1 + len(df)))

print("-------------------------------")
print(df.info())
print("-------------------------------")

#print(df.head(10))
#print(df.tail)
print(df.loc[236])
print(df.loc[251])
print(df.loc[682])
print(df.loc[1220])
print(df.loc[1221])
print(df.loc[1322])

meanAirTmp = df["avgAirTemperature"].mean()
meanPrecipitation = df["precipitation"].mean()
meanMinAirTemperature = df["minAirTemperature"].mean()
meanMaxAirTemperature = df["maxAirTemperature"].mean()

df["avgAirTemperature"].fillna(meanAirTmp, inplace=True)
df["precipitation"].fillna(meanPrecipitation, inplace=True)
df["minAirTemperature"].fillna(meanMinAirTemperature, inplace=True)
df["maxAirTemperature"].fillna(meanMaxAirTemperature, inplace=True)

print("-------------------------------")

print(df.loc[236])
print(df.loc[251])
print(df.loc[682])
print(df.loc[1220])
print(df.loc[1221])
print(df.loc[1322])
# Out:
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   lastUpdated                            3487 non-null   object
#  1   weatherStation.name                    3487 non-null   object
#  2   weatherStation.province                3487 non-null   object
#  3   weatherStation.location.coordinates.0  3487 non-null   float64
#  4   weatherStation.location.coordinates.1  3487 non-null   float64
#  5   avgAirTemperature                      3458 non-null   float64
#  6   precipitation                          3480 non-null   float64
#  7   minAirTemperature                      3468 non-null   float64
#  8   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 245.3+ KB
# None
# -------------------------------
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ID                                     3487 non-null   int64
#  1   lastUpdated                            3487 non-null   object
#  2   weatherStation.name                    3487 non-null   object
#  3   weatherStation.province                3487 non-null   object
#  4   weatherStation.location.coordinates.0  3487 non-null   float64
#  5   weatherStation.location.coordinates.1  3487 non-null   float64
#  6   avgAirTemperature                      3458 non-null   float64
#  7   precipitation                          3480 non-null   float64
#  8   minAirTemperature                      3468 non-null   float64
#  9   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 272.5+ KB
# None
# -------------------------------
# ID                                                            237
# lastUpdated                              2023-11-16T20:38:38.276Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 NaN
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 236, dtype: object
# ID                                                            252
# lastUpdated                              2023-11-16T20:38:38.302Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 251, dtype: object
# ID                                                            683
# lastUpdated                              2023-11-16T20:49:47.780Z
# weatherStation.name                                     PORQUERES
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   42.104444
# weatherStation.location.coordinates.1                    2.763611
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 682, dtype: object
# ID                                                           1221
# lastUpdated                              2023-11-20T10:42:29.123Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1220, dtype: object
# ID                                                           1222
# lastUpdated                              2023-11-20T10:42:29.124Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1221, dtype: object
# ID                                                           1323
# lastUpdated                              2023-11-20T10:42:29.226Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1322, dtype: object
# -------------------------------
# ID                                                            237
# lastUpdated                              2023-11-16T20:38:38.276Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                       15.415211
# precipitation                                            0.760287
# minAirTemperature                                       10.094896
# maxAirTemperature                                       21.020908
# Name: 236, dtype: object
# ID                                                            252
# lastUpdated                              2023-11-16T20:38:38.302Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                       15.415211
# precipitation                                                 0.0
# minAirTemperature                                       10.094896
# maxAirTemperature                                       21.020908
# Name: 251, dtype: object
# ID                                                            683
# lastUpdated                              2023-11-16T20:49:47.780Z
# weatherStation.name                                     PORQUERES
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   42.104444
# weatherStation.location.coordinates.1                    2.763611
# avgAirTemperature                                       15.415211
# precipitation                                                 0.0
# minAirTemperature                                       10.094896
# maxAirTemperature                                       21.020908
# Name: 682, dtype: object
# ID                                                           1221
# lastUpdated                              2023-11-20T10:42:29.123Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                       15.415211
# precipitation                                                 0.0
# minAirTemperature                                       10.094896
# maxAirTemperature                                       21.020908
# Name: 1220, dtype: object
# ID                                                           1222
# lastUpdated                              2023-11-20T10:42:29.124Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                       15.415211
# precipitation                                                 0.0
# minAirTemperature                                       10.094896
# maxAirTemperature                                       21.020908
# Name: 1221, dtype: object
# ID                                                           1323
# lastUpdated                              2023-11-20T10:42:29.226Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                       15.415211
# precipitation                                                 0.0
# minAirTemperature                                       10.094896
# maxAirTemperature                                       21.020908
# Name: 1322, dtype: object

# %%
import pandas as pd

#pd.options.display.max_rows = 9999
df = pd.read_csv('weatherData.csv')

#print(df)
print("-------------------------------")
print(df.info())
print("-------------------------------")

df.insert(0, 'ID', range(1, 1 + len(df)))

print("-------------------------------")
print(df.info())
print("-------------------------------")

#print(df.head(10))
#print(df.tail)
print(df.loc[236])
print(df.loc[251])
print(df.loc[682])
print(df.loc[1220])
print(df.loc[1221])
print(df.loc[1322])

##
## Median ([2, 4, 6, 8]) = (4 + 6) / 2 = 5.
##
medianAirTmp = df["avgAirTemperature"].median()
medianPrecipitation = df["precipitation"].median()
medianMinAirTemperature = df["minAirTemperature"].median()
medianMaxAirTemperature = df["maxAirTemperature"].median()

df["avgAirTemperature"].fillna(medianAirTmp, inplace=True)
df["precipitation"].fillna(meanPrecipitation, inplace=True)
df["minAirTemperature"].fillna(medianPrecipitation, inplace=True)
df["maxAirTemperature"].fillna(medianMaxAirTemperature, inplace=True)

print("-------------------------------")

print(df.loc[236])
print(df.loc[251])
print(df.loc[682])
print(df.loc[1220])
print(df.loc[1221])
print(df.loc[1322])
# Out:
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   lastUpdated                            3487 non-null   object
#  1   weatherStation.name                    3487 non-null   object
#  2   weatherStation.province                3487 non-null   object
#  3   weatherStation.location.coordinates.0  3487 non-null   float64
#  4   weatherStation.location.coordinates.1  3487 non-null   float64
#  5   avgAirTemperature                      3458 non-null   float64
#  6   precipitation                          3480 non-null   float64
#  7   minAirTemperature                      3468 non-null   float64
#  8   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 245.3+ KB
# None
# -------------------------------
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ID                                     3487 non-null   int64
#  1   lastUpdated                            3487 non-null   object
#  2   weatherStation.name                    3487 non-null   object
#  3   weatherStation.province                3487 non-null   object
#  4   weatherStation.location.coordinates.0  3487 non-null   float64
#  5   weatherStation.location.coordinates.1  3487 non-null   float64
#  6   avgAirTemperature                      3458 non-null   float64
#  7   precipitation                          3480 non-null   float64
#  8   minAirTemperature                      3468 non-null   float64
#  9   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 272.5+ KB
# None
# -------------------------------
# ID                                                            237
# lastUpdated                              2023-11-16T20:38:38.276Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 NaN
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 236, dtype: object
# ID                                                            252
# lastUpdated                              2023-11-16T20:38:38.302Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 251, dtype: object
# ID                                                            683
# lastUpdated                              2023-11-16T20:49:47.780Z
# weatherStation.name                                     PORQUERES
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   42.104444
# weatherStation.location.coordinates.1                    2.763611
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 682, dtype: object
# ID                                                           1221
# lastUpdated                              2023-11-20T10:42:29.123Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1220, dtype: object
# ID                                                           1222
# lastUpdated                              2023-11-20T10:42:29.124Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1221, dtype: object
# ID                                                           1323
# lastUpdated                              2023-11-20T10:42:29.226Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1322, dtype: object
# -------------------------------
# ID                                                            237
# lastUpdated                              2023-11-16T20:38:38.276Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                           14.45
# precipitation                                            0.760287
# minAirTemperature                                             0.0
# maxAirTemperature                                            20.3
# Name: 236, dtype: object
# ID                                                            252
# lastUpdated                              2023-11-16T20:38:38.302Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                           14.45
# precipitation                                                 0.0
# minAirTemperature                                             0.0
# maxAirTemperature                                            20.3
# Name: 251, dtype: object
# ID                                                            683
# lastUpdated                              2023-11-16T20:49:47.780Z
# weatherStation.name                                     PORQUERES
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   42.104444
# weatherStation.location.coordinates.1                    2.763611
# avgAirTemperature                                           14.45
# precipitation                                                 0.0
# minAirTemperature                                             0.0
# maxAirTemperature                                            20.3
# Name: 682, dtype: object
# ID                                                           1221
# lastUpdated                              2023-11-20T10:42:29.123Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                           14.45
# precipitation                                                 0.0
# minAirTemperature                                             0.0
# maxAirTemperature                                            20.3
# Name: 1220, dtype: object
# ID                                                           1222
# lastUpdated                              2023-11-20T10:42:29.124Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                           14.45
# precipitation                                                 0.0
# minAirTemperature                                             0.0
# maxAirTemperature                                            20.3
# Name: 1221, dtype: object
# ID                                                           1323
# lastUpdated                              2023-11-20T10:42:29.226Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                           14.45
# precipitation                                                 0.0
# minAirTemperature                                             0.0
# maxAirTemperature                                            20.3
# Name: 1322, dtype: object

# %%
import pandas as pd

#pd.options.display.max_rows = 9999
df = pd.read_csv('weatherData.csv')

#print(df)
print("-------------------------------")
print(df.info())
print("-------------------------------")

df.insert(0, 'ID', range(1, 1 + len(df)))

print("-------------------------------")
print(df.info())
print("-------------------------------")

#print(df.head(10))
#print(df.tail)
print(df.loc[236])
print(df.loc[251])
print(df.loc[682])
print(df.loc[1220])
print(df.loc[1221])
print(df.loc[1322])


###
### Mode ([1, 2, 2, 3, 4, 4, 4] = 4
###
modeAirTmp = df["avgAirTemperature"].mode()
modePrecipitation = df["precipitation"].mode()
modeMinAirTemperature = df["minAirTemperature"].mode()
modeMaxAirTemperature = df["maxAirTemperature"].mode()

df["avgAirTemperature"].fillna(modeAirTmp, inplace=True)
df["precipitation"].fillna(modePrecipitation, inplace=True)
df["minAirTemperature"].fillna(modeMinAirTemperature, inplace=True)
df["maxAirTemperature"].fillna(modeMaxAirTemperature, inplace=True)

print("-------------------------------")

print(df.loc[236])
print(df.loc[251])
print(df.loc[682])
print(df.loc[1220])
print(df.loc[1221])
print(df.loc[1322])
# Out:
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   lastUpdated                            3487 non-null   object
#  1   weatherStation.name                    3487 non-null   object
#  2   weatherStation.province                3487 non-null   object
#  3   weatherStation.location.coordinates.0  3487 non-null   float64
#  4   weatherStation.location.coordinates.1  3487 non-null   float64
#  5   avgAirTemperature                      3458 non-null   float64
#  6   precipitation                          3480 non-null   float64
#  7   minAirTemperature                      3468 non-null   float64
#  8   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 245.3+ KB
# None
# -------------------------------
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ID                                     3487 non-null   int64
#  1   lastUpdated                            3487 non-null   object
#  2   weatherStation.name                    3487 non-null   object
#  3   weatherStation.province                3487 non-null   object
#  4   weatherStation.location.coordinates.0  3487 non-null   float64
#  5   weatherStation.location.coordinates.1  3487 non-null   float64
#  6   avgAirTemperature                      3458 non-null   float64
#  7   precipitation                          3480 non-null   float64
#  8   minAirTemperature                      3468 non-null   float64
#  9   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 272.5+ KB
# None
# -------------------------------
# ID                                                            237
# lastUpdated                              2023-11-16T20:38:38.276Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 NaN
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 236, dtype: object
# ID                                                            252
# lastUpdated                              2023-11-16T20:38:38.302Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 251, dtype: object
# ID                                                            683
# lastUpdated                              2023-11-16T20:49:47.780Z
# weatherStation.name                                     PORQUERES
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   42.104444
# weatherStation.location.coordinates.1                    2.763611
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 682, dtype: object
# ID                                                           1221
# lastUpdated                              2023-11-20T10:42:29.123Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1220, dtype: object
# ID                                                           1222
# lastUpdated                              2023-11-20T10:42:29.124Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1221, dtype: object
# ID                                                           1323
# lastUpdated                              2023-11-20T10:42:29.226Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1322, dtype: object
# -------------------------------
# ID                                                            237
# lastUpdated                              2023-11-16T20:38:38.276Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 NaN
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 236, dtype: object
# ID                                                            252
# lastUpdated                              2023-11-16T20:38:38.302Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 251, dtype: object
# ID                                                            683
# lastUpdated                              2023-11-16T20:49:47.780Z
# weatherStation.name                                     PORQUERES
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   42.104444
# weatherStation.location.coordinates.1                    2.763611
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 682, dtype: object
# ID                                                           1221
# lastUpdated                              2023-11-20T10:42:29.123Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1220, dtype: object
# ID                                                           1222
# lastUpdated                              2023-11-20T10:42:29.124Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1221, dtype: object
# ID                                                           1323
# lastUpdated                              2023-11-20T10:42:29.226Z
# weatherStation.name                             GIRONA AEROPUERTO
# weatherStation.province                                    GIRONA
# weatherStation.location.coordinates.0                   41.911667
# weatherStation.location.coordinates.1                    2.763333
# avgAirTemperature                                             NaN
# precipitation                                                 0.0
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 1322, dtype: object

# %% [markdown]
# Wrong Format

# %%
import pandas as pd

#pd.options.display.max_rows = 9999
df = pd.read_csv('weatherData.csv')

#print(df)
print("-------------------------------")
print(df.info())
print("-------------------------------")

df.insert(0, 'ID', range(1, 1 + len(df)))

print("-------------------------------")
print(df.info())
print("-------------------------------")

print(df.loc[236])

df['lastUpdated'] = pd.to_datetime(df['lastUpdated'])

print(df.loc[236])

## 2 decimales para lat / long
df['weatherStation.location.coordinates.0'] = df['weatherStation.location.coordinates.0'].round(2)
df['weatherStation.location.coordinates.1'] = df['weatherStation.location.coordinates.1'].round(2)

df.loc[236, 'avgAirTemperature']=20
df.loc[236, 'precipitation']=200
df.loc[236, 'minAirTemperature']=5
df.loc[236, 'maxAirTemperature']=70
print(df.loc[236])


## Se modifica la máxima temperatura deel aire en el
# caso que supere los 50 grados
for x in df.index:
  if df.loc[x, "maxAirTemperature"] > 50:
    df.loc[x, "maxAirTemperature"] = 50

print(df.loc[236])

df = df.rename(columns={'weatherStation.province': 'province'})

print(df.loc[236])


filas_filtradas = df.query('province == "GIRONA"')
numFilas = filas_filtradas.shape[0]
print("-------------------------------")
print(numFilas)
print("-------------------------------")
print(filas_filtradas.head(3))

for x in df.index:
  if df.loc[x, "province"] == 'GIRONA':
    df.drop(x, inplace = True)

filas_filtradas = df.query('province == "GIRONA"')
numFilas = filas_filtradas.shape[0]
print("-------------------------------")
print(numFilas)
print("-------------------------------")
# Out:
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   lastUpdated                            3487 non-null   object
#  1   weatherStation.name                    3487 non-null   object
#  2   weatherStation.province                3487 non-null   object
#  3   weatherStation.location.coordinates.0  3487 non-null   float64
#  4   weatherStation.location.coordinates.1  3487 non-null   float64
#  5   avgAirTemperature                      3458 non-null   float64
#  6   precipitation                          3480 non-null   float64
#  7   minAirTemperature                      3468 non-null   float64
#  8   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 245.3+ KB
# None
# -------------------------------
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ID                                     3487 non-null   int64
#  1   lastUpdated                            3487 non-null   object
#  2   weatherStation.name                    3487 non-null   object
#  3   weatherStation.province                3487 non-null   object
#  4   weatherStation.location.coordinates.0  3487 non-null   float64
#  5   weatherStation.location.coordinates.1  3487 non-null   float64
#  6   avgAirTemperature                      3458 non-null   float64
#  7   precipitation                          3480 non-null   float64
#  8   minAirTemperature                      3468 non-null   float64
#  9   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 272.5+ KB
# None
# -------------------------------
# ID                                                            237
# lastUpdated                              2023-11-16T20:38:38.276Z
# weatherStation.name                                       MANRESA
# weatherStation.province                                 BARCELONA
# weatherStation.location.coordinates.0                       41.72
# weatherStation.location.coordinates.1                    1.840278
# avgAirTemperature                                             NaN
# precipitation                                                 NaN
# minAirTemperature                                             NaN
# maxAirTemperature                                             NaN
# Name: 236, dtype: object
# ID                                                                    237
# lastUpdated                              2023-11-16 20:38:38.276000+00:00
# weatherStation.name                                               MANRESA
# weatherStation.province                                         BARCELONA
# weatherStation.location.coordinates.0                               41.72
# weatherStation.location.coordinates.1                            1.840278
# avgAirTemperature                                                     NaN
# precipitation                                                         NaN
# minAirTemperature                                                     NaN
# maxAirTemperature                                                     NaN
# Name: 236, dtype: object
# ID                                                                    237
# lastUpdated                              2023-11-16 20:38:38.276000+00:00
# weatherStation.name                                               MANRESA
# weatherStation.province                                         BARCELONA
# weatherStation.location.coordinates.0                               41.72
# weatherStation.location.coordinates.1                                1.84
# avgAirTemperature                                                    20.0
# precipitation                                                       200.0
# minAirTemperature                                                     5.0
# maxAirTemperature                                                    70.0
# Name: 236, dtype: object
# ID                                                                    237
# lastUpdated                              2023-11-16 20:38:38.276000+00:00
# weatherStation.name                                               MANRESA
# weatherStation.province                                         BARCELONA
# weatherStation.location.coordinates.0                               41.72
# weatherStation.location.coordinates.1                                1.84
# avgAirTemperature                                                    20.0
# precipitation                                                       200.0
# minAirTemperature                                                     5.0
# maxAirTemperature                                                    50.0
# Name: 236, dtype: object
# ID                                                                    237
# lastUpdated                              2023-11-16 20:38:38.276000+00:00
# weatherStation.name                                               MANRESA
# province                                                        BARCELONA
# weatherStation.location.coordinates.0                               41.72
# weatherStation.location.coordinates.1                                1.84
# avgAirTemperature                                                    20.0
# precipitation                                                       200.0
# minAirTemperature                                                     5.0
# maxAirTemperature                                                    50.0
# Name: 236, dtype: object
# -------------------------------
# 852
# -------------------------------
#       ID                      lastUpdated weatherStation.name province  \
# 375  376 2023-11-16 20:49:47.189000+00:00           PORQUERES   GIRONA
# 376  377 2023-11-16 20:49:47.194000+00:00           PORQUERES   GIRONA
# 377  378 2023-11-16 20:49:47.197000+00:00           PORQUERES   GIRONA
#
#      weatherStation.location.coordinates.0  \
# 375                                   42.1
# 376                                   42.1
# 377                                   42.1
#
#      weatherStation.location.coordinates.1  avgAirTemperature  precipitation  \
# 375                                   2.76               17.7            0.0
# 376                                   2.76               16.7            0.0
# 377                                   2.76               16.2            0.0
#
#      minAirTemperature  maxAirTemperature
# 375               11.9               23.5
# 376               10.8               22.6
# 377               11.0               21.3
# -------------------------------
# 0
# -------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt

#pd.options.display.max_rows = 9999
df = pd.read_csv('weatherData.csv')

print(df.info())
df['lastUpdated'] = pd.to_datetime(df['lastUpdated'])

df = df.drop('weatherStation.name', axis=1)
df = df.drop('weatherStation.province', axis=1)
df = df.drop('weatherStation.location.coordinates.0', axis=1)
df = df.drop('weatherStation.location.coordinates.1', axis=1)


###
print(df.corr())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   lastUpdated                            3487 non-null   object
#  1   weatherStation.name                    3487 non-null   object
#  2   weatherStation.province                3487 non-null   object
#  3   weatherStation.location.coordinates.0  3487 non-null   float64
#  4   weatherStation.location.coordinates.1  3487 non-null   float64
#  5   avgAirTemperature                      3458 non-null   float64
#  6   precipitation                          3480 non-null   float64
#  7   minAirTemperature                      3468 non-null   float64
#  8   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 245.3+ KB
# None
#                    lastUpdated  avgAirTemperature  precipitation  \
# lastUpdated           1.000000          -0.314057      -0.059228
# avgAirTemperature    -0.314057           1.000000       0.023077
# precipitation        -0.059228           0.023077       1.000000
# minAirTemperature    -0.287832           0.952472       0.047328
# maxAirTemperature    -0.278037           0.950346      -0.010075
#
#                    minAirTemperature  maxAirTemperature
# lastUpdated                -0.287832          -0.278037
# avgAirTemperature           0.952472           0.950346
# precipitation               0.047328          -0.010075
# minAirTemperature           1.000000           0.818873
# maxAirTemperature           0.818873           1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

#pd.options.display.max_rows = 9999
df = pd.read_csv('weatherData.csv')

print(df.info())
df['lastUpdated'] = pd.to_datetime(df['lastUpdated'])

df = df.drop('weatherStation.name', axis=1)
df = df.drop('weatherStation.location.coordinates.0', axis=1)
df = df.drop('weatherStation.location.coordinates.1', axis=1)


###
##print(df.corr())

df.plot(kind = 'scatter', x = 'precipitation', y = 'lastUpdated')

plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   lastUpdated                            3487 non-null   object
#  1   weatherStation.name                    3487 non-null   object
#  2   weatherStation.province                3487 non-null   object
#  3   weatherStation.location.coordinates.0  3487 non-null   float64
#  4   weatherStation.location.coordinates.1  3487 non-null   float64
#  5   avgAirTemperature                      3458 non-null   float64
#  6   precipitation                          3480 non-null   float64
#  7   minAirTemperature                      3468 non-null   float64
#  8   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 245.3+ KB
# None

# %%
import pandas as pd
import matplotlib.pyplot as plt

#pd.options.display.max_rows = 9999
df = pd.read_csv('weatherData.csv')

print(df.info())
df['lastUpdated'] = pd.to_datetime(df['lastUpdated'])

df = df.drop('weatherStation.name', axis=1)
#df = df.drop('weatherStation.province', axis=1)
df = df.drop('weatherStation.location.coordinates.0', axis=1)
df = df.drop('weatherStation.location.coordinates.1', axis=1)


###
##print(df.corr())

df['precipitation'].plot(kind = 'hist')

plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   lastUpdated                            3487 non-null   object
#  1   weatherStation.name                    3487 non-null   object
#  2   weatherStation.province                3487 non-null   object
#  3   weatherStation.location.coordinates.0  3487 non-null   float64
#  4   weatherStation.location.coordinates.1  3487 non-null   float64
#  5   avgAirTemperature                      3458 non-null   float64
#  6   precipitation                          3480 non-null   float64
#  7   minAirTemperature                      3468 non-null   float64
#  8   maxAirTemperature                      3458 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 245.3+ KB
# None
